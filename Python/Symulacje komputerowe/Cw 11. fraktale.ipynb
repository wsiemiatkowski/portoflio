# %% [markdown]
# ## W poniższym okienku proszę wpisać swoje **imię, nazwisko i numer grupy**.

# %% [markdown]
# *   Imię: Wojciech
# *   Nazwisko: Siemiątkowski
# *   Grupa: 12c

# %% [markdown]
# # **Wprowadzenie: L-system**
#
# L-systemem nazywamy trójkę: $(V,w,D)$, gdzie:
#
# $V$ - alfabet,
#
# $w$ - aksjomant, symbol początkowy,
#
# $D$ - zestaw reguł produkcyjnych.
#
# > **Przykład 1**
#
# > zmienne: A, B
#
# > aksjomat: A
#
# >  reguły: $(A \to AB),(B \to A). $
#
# *Idea: przypisując symbolom polecenia dla urządzenia rysującego można stworzyć fraktale.*
#
# *   $F$ - rysuj do przodu
# *   $f$ - idz do przodu, ale nie rysuj (podnieś pisak, przejdz, połóż pisak spowrotem)
# *   $+$ - skręc w lewo
# *   $-$ - skęc w prawo
# *   [ - wrzuć bieżący stan na stos (push)
# *   ] - bieżącym stanem ma się stać stan ze szczytu stosu (pop)
#
#
# ### Czym są fraktale i do czego służą? Zobacz film:
#
#  https://youtu.be/WFtTdf3I6Ug (~4 min)
#
# Apka do zabawy fraktalami, również 3d, jest dostępna [tu](http://www.alife.pl/lsyst/p).

# %%
# Fraktale rysuje dla nas żółw z biblioteki ColabTurtle:
# https://docs.python.org/3/library/turtle.html

# !pip3 install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7657 sha256=9eec63774ff15ace3d81ba90951f1e360dc18ea5bfebdcdedba16bf82a6cd39b
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as franklin

help(franklin)
# Out:
# Help on module ColabTurtle.Turtle in ColabTurtle:
#
# NAME
#     ColabTurtle.Turtle
#
# FUNCTIONS
#     back = backward(units)
#         # makes the turtle move backward by 'units' units
#
#     backward(units)
#         # makes the turtle move backward by 'units' units
#
#     bgcolor(color=None, c2=None, c3=None)
#         # change the background color of the drawing area
#         # if no params, return the current background color
#
#     bk = backward(units)
#         # makes the turtle move backward by 'units' units
#
#     clear()
#         # clear any text or drawing on the screen
#
#     color(color=None, c2=None, c3=None)
#         # change the color of the pen
#         # if no params, return the current pen color
#
#     distance(x, y=None)
#         # calculate the distance between the turtle and a given point
#
#     down = pendown()
#         # lowers the pen such that following turtle moves will now cause drawings
#
#     face(degrees)
#         # makes the turtle face a given direction
#
#     fd = forward(units)
#         # makes the turtle move forward by 'units' units
#
#     forward(units)
#         # makes the turtle move forward by 'units' units
#
#     getheading()
#         # retrieve the turtle's current angle
#
#     getx()
#         # retrieve the turtle's currrent 'x' x-coordinate
#
#     gety()
#         # retrieve the turtle's currrent 'y' y-coordinate
#
#     goto(x, y=None)
#         # move the turtle to a designated 'x'-'y' coordinate
#
#     heading = getheading()
#         # retrieve the turtle's current angle
#
#     hideturtle()
#         # switch turtle visibility to OFF
#
#     home()
#
#     ht = hideturtle()
#         # switch turtle visibility to OFF
#
#     initializeTurtle(initial_speed=4, initial_window_size=(800, 500))
#         # construct the display for turtle
#
#     isdown()
#
#     isvisible()
#
#     left(degrees)
#         # makes the turtle move right by 'degrees' degrees (NOT radians, this library does not support radians right now)
#
#     lt = left(degrees)
#         # makes the turtle move right by 'degrees' degrees (NOT radians, this library does not support radians right now)
#
#     pd = pendown()
#         # lowers the pen such that following turtle moves will now cause drawings
#
#     pencolor = color(color=None, c2=None, c3=None)
#         # change the color of the pen
#         # if no params, return the current pen color
#
#     pendown()
#         # lowers the pen such that following turtle moves will now cause drawings
#
#     pensize = width(width=None)
#         # change the width of the lines drawn by the turtle, in pixels
#         # if the function is called without arguments, it returns the current width
#
#     penup()
#         # raises the pen such that following turtle moves will not cause any drawings
#
#     pos = position()
#         # retrieve the turtle's current position as a (x,y) tuple vector
#
#     position()
#         # retrieve the turtle's current position as a (x,y) tuple vector
#
#     pu = penup()
#         # raises the pen such that following turtle moves will not cause any drawings
#
#     right(degrees)
#         # makes the turtle move right by 'degrees' degrees (NOT radians)
#
#     rt = right(degrees)
#         # makes the turtle move right by 'degrees' degrees (NOT radians)
#
#     seth = face(degrees)
#         # makes the turtle face a given direction
#
#     setheading = face(degrees)
#         # makes the turtle face a given direction
#
#     setpos = goto(x, y=None)
#         # move the turtle to a designated 'x'-'y' coordinate
#
#     setposition = goto(x, y=None)
#         # move the turtle to a designated 'x'-'y' coordinate
#
#     setx(x)
#         # move the turtle to a designated 'x' x-coordinate, y-coordinate stays the same
#
#     sety(y)
#         # move the turtle to a designated 'y' y-coordinate, x-coordinate stays the same
#
#     shape(shape=None)
#
#     showturtle()
#         # switch turtle visibility to ON
#
#     speed(speed=None)
#         # update the speed of the moves, [1,13]
#         # if argument is omitted, it returns the speed.
#
#     st = showturtle()
#         # switch turtle visibility to ON
#
#     up = penup()
#         # raises the pen such that following turtle moves will not cause any drawings
#
#     width(width=None)
#         # change the width of the lines drawn by the turtle, in pixels
#         # if the function is called without arguments, it returns the current width
#
#     window_height()
#         # return turtle window height
#
#     window_width()
#         # return turtle window width
#
#     write(obj, **kwargs)
#
#     xcor = getx()
#         # retrieve the turtle's currrent 'x' x-coordinate
#
#     ycor = gety()
#         # retrieve the turtle's currrent 'y' y-coordinate
#
# DATA
#     DEFAULT_BACKGROUND_COLOR = 'black'
#     DEFAULT_IS_PEN_DOWN = True
#     DEFAULT_PEN_COLOR = 'white'
#     DEFAULT_PEN_WIDTH = 4
#     DEFAULT_SPEED = 4
#     DEFAULT_SVG_LINES_STRING = ''
#     DEFAULT_TURTLE_DEGREE = 270
#     DEFAULT_TURTLE_SHAPE = 'turtle'
#     DEFAULT_TURTLE_VISIBILITY = True
#     DEFAULT_WINDOW_SIZE = (800, 500)
#     SPEED_TO_SEC_MAP = {1: 1.5, 2: 0.9, 3: 0.7, 4: 0.5, 5: 0.3, 6: 0.18, 7...
#     SVG_TEMPLATE = '\n      <svg width="{window_width}" height="{wind...  ...
#     TURTLE_CIRCLE_SVG_TEMPLATE = '\n      <g visibility={visibility} trans...
#     TURTLE_TURTLE_SVG_TEMPLATE = '<g visibility={visibility} transform="ro...
#     VALID_COLORS = ('black', 'navy', 'darkblue', 'mediumblue', 'blue', 'da...
#     VALID_COLORS_SET = {'aliceblue', 'antiquewhite', 'aqua', 'aquamarine',...
#     VALID_TURTLE_SHAPES = ('turtle', 'circle')
#     background_color = 'black'
#     drawing_window = None
#     is_pen_down = True
#     is_turtle_visible = True
#     pen_color = 'white'
#     pen_width = 4
#     svg_lines_string = ''
#     turtle_degree = 270
#     turtle_pos = (400, 250)
#     turtle_shape = 'turtle'
#     turtle_speed = 4
#     window_size = (800, 500)
#
# FILE
#     /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py

# %%
# Źródło kodu:
# https://gist.github.com/bbengfort/11183420

# Importujemy bibliotekę i nazywamy naszego żółwia


def iterate(rules, num=0, start='F'):
    """
    Tu wyliczane są kolejne iteracje układu, poczynając od start
    """

    def translate(current, rules):
        """
        W aktualnym stanie układu (current) podmienia wszystkie
        wystąpienia F na aksjomat, a stałe consts przepisuje
        """
        result = ''
        consts = {'+', '-', '[', ']'}
        for c in current:
            if c in consts:
                result += c
                continue
            if c == 'F':
                result += rules
        return result

    # Ustalamy początkowy rozkład na 'start'
    result = start
    for i in range(0, num):
        # Przy każdej iteracji stosujemy zdefiniowane reguły 'rules'
        result = translate(result, rules)
    return result


def draw(lsystem, d=90, l=10, speed=13, sx=500, sy=500, penwidth=3):
    """
       Prosi żółwia o narysowanie wyliczonego L-systemu

       lsystem  - lista
       d        - kąt o który skręca żółw, gdy przeczyta '+' lub '-'
       l        - długość kroku żółwia
       speed    - prędkość żołwia (13 to max)
       sx       - szerokość okna
       sy       - wysokość okna
       penwidth - grubość pisaka

    """
    # lista na którą wrzucamy pozycję żółwia jeśli pojawi się '['
    # lub z której pozycję żółwia zczytujemy jeśli pojawi się ']'
    stack  = []

    # Ustawienie okna i początkowa pozycja żółwia
    window_size_x = sx
    window_size_y = sy
    franklin.initializeTurtle(initial_speed=speed,
                              initial_window_size=(window_size_x, window_size_y))
    franklin.hideturtle()
    franklin.setheading(90)
    franklin.speed(speed)
    franklin.color('green')
    franklin.penup()
    franklin.goto(window_size_x*0.5,window_size_y*0.2)
    franklin.pendown()
    franklin.pensize(width=penwidth)

    # Pętla po całym l-system'ie tłumacząca kolejne znaki na ruch żółwia
    for i in range(len(lsystem)):
        c = lsystem[i]

        if c == 'F':
            franklin.forward(l)

        if c == 'f':
            franklin.penup()
            franklin.forward(l)
            franklin.pendown()

        if c == '+':
            franklin.left(d)

        if c == '-':
            franklin.right(d)

        if c == '[':
            stack.append((franklin.heading(), franklin.pos()))

        if c == ']':
            heading, position = stack.pop()
            franklin.penup()
            franklin.goto(position)
            franklin.setheading(heading)
            franklin.pendown()

# %%
# Płatek śniegu Kocha
rules = "F+F--F+F"
lsystem = iterate(rules, 2, "F--F--F")
draw(lsystem, 60, 7, 6, 400, 400, 1)

del lsystem
# Out:
#       <svg width="400" height="400">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="200.0" y1="80.0" x2="200.0" y2="87.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="87.0" x2="206.062" y2="90.5" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="206.062" y1="90.5" x2="200.0" y2="94.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="94.0" x2="200.0" y2="101.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="101.0" x2="206.062" y2="104.5" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="206.062" y1="104.5" x2="212.124" y2="101.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="212.124" y1="101.0" x2="212.124" y2="108.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="212.124" y1="108.0" x2="218.186" y2="111.5" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="218.186" y1="111.5" x2="212.124" y2="115.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="212.124" y1="115.0" x2="212.124" y2="122.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="212.124" y1="122.0" x2="206.062" y2="118.5" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="206.062" y1="118.5" x2="200.0" y2="122.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="122.0" x2="200.0" y2="129.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="129.0" x2="206.062" y2="132.5" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="206.062" y1="132.5" x2="200.0" y2="136.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="136.0" x2="200.0" y2="143.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="200.0" y1="143.0" x2="193.938" y2="139.5" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="193.938" y1="139.5" x2="187.876" y2="143.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/>
#         <g visibility=hidden transform="rotate(360,187.876,143.0) translate(169.876, 125.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:green;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-25f75a29613d> in <module>()
#       2 rules = "F+F--F+F"
#       3 lsystem = iterate(rules, 2, "F--F--F")
# ----> 4 draw(lsystem, 60, 7, 6, 400, 400, 1)
#       5
#       6 del lsystem
#
# <ipython-input-3-eadd2b28d980> in draw(lsystem, d, l, speed, sx, sy, penwidth)
#      69
#      70         if c == 'F':
# ---> 71             franklin.forward(l)
#      72
#      73         if c == 'f':
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in forward(units)
#     172     ending_point = (turtle_pos[0] + units * math.cos(alpha), turtle_pos[1] + units * math.sin(alpha))
#     173
# --> 174     _moveToNewPosition(ending_point)
#     175
#     176 fd = forward # alias
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in _moveToNewPosition(new_pos)
#     161
#     162     turtle_pos = new_pos
# --> 163     _updateDrawing()
#     164
#     165
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in _updateDrawing()
#     143     if drawing_window == None:
#     144         raise AttributeError("Display has not been initialized yet. Call initializeTurtle() before using.")
# --> 145     time.sleep(_speedToSec(turtle_speed))
#     146     drawing_window.update(HTML(_generateSvgDrawing()))
#     147
#
# KeyboardInterrupt:

# %%
rules = "F-F+F+F-F"
lsystem = iterate(rules, 3, "F")
draw(lsystem, 90, 10, 13)

del lsystem
# Out:
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="100.0" x2="250.0" y2="110.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="110.0" x2="240.0" y2="110.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="110.0" x2="240.0" y2="120.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="120.0" x2="250.0" y2="120.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="120.0" x2="250.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="130.0" x2="240.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="130.0" x2="240.0" y2="120.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="120.0" x2="230.0" y2="120.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="120.0" x2="230.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="130.0" x2="220.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="130.0" x2="220.0" y2="140.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="140.0" x2="210.0" y2="140.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="210.0" y1="140.0" x2="210.0" y2="150.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="210.0" y1="150.0" x2="220.0" y2="150.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="150.0" x2="220.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="160.0" x2="230.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="160.0" x2="230.0" y2="170.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="170.0" x2="240.0" y2="170.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="170.0" x2="240.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="160.0" x2="250.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="160.0" x2="250.0" y2="170.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="170.0" x2="240.0" y2="170.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="170.0" x2="240.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="180.0" x2="250.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="180.0" x2="250.0" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="190.0" x2="240.0" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="190.0" x2="240.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="240.0" y1="180.0" x2="230.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="180.0" x2="230.0" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="190.0" x2="220.0" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="190.0" x2="220.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="180.0" x2="230.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="180.0" x2="230.0" y2="170.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="230.0" y1="170.0" x2="220.0" y2="170.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="170.0" x2="220.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.0" y1="160.0" x2="210.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="210.0" y1="160.0" x2=" ...

# %% [markdown]
# # **Zadania**
#
# ### **Zadanie 1 - uogólnienie kodu**
#
# Zmodyfikuj kod tak, żeby obsługiwał więcej niż jedną literę i regułę:
#
# *Podpowiedź przechowuj reguły w słowniku postaci: {"litera":"reguła"}*

# %%
def iterate(rules, num=0, start='F'):
    """
    Tu wyliczane są kolejne iteracje układu, poczynając od start
    """

    def translate(current, rules):
        """
        W aktualnym stanie układu (current) podmienia wszystkie
        wystąpienia F na aksjomat, a stałe consts przepisuje
        """
        result = ''
        consts = {'+', '-', '[', ']'}
        for c in current:
            if c in consts:
                result += c
            else:
                result += rules[c]
        return result

    # Ustalamy początkowy rozkład na 'start'
    result = start
    for i in range(0, num):
        # Przy każdej iteracji stosujemy zdefiniowane reguły 'rules'
        result = translate(result, rules)
    return result


def draw(lsystem, d=90, l=10, speed=13, sx=500, sy=500, penwidth=3):
    """
       Prosi żółwia o narysowanie wyliczonego L-systemu

       lsystem  - lista
       d        - kąt o który skręca żółw, gdy przeczyta '+' lub '-'
       l        - długość kroku żółwia
       speed    - prędkość żołwia (13 to max)
       sx       - szerokość okna
       sy       - wysokość okna
       penwidth - grubość pisaka

    """
    # lista na którą wrzucamy pozycję żółwia jeśli pojawi się '['
    # lub z której pozycję żółwia zczytujemy jeśli pojawi się ']'
    stack  = []

    # Ustawienie okna i początkowa pozycja żółwia
    window_size_x = sx
    window_size_y = sy
    franklin.initializeTurtle(initial_speed=speed,
                              initial_window_size=(window_size_x, window_size_y))
    franklin.hideturtle()
    franklin.setheading(90)
    franklin.speed(speed)
    franklin.color('green')
    franklin.penup()
    franklin.goto(window_size_x*0.5,window_size_y*0.2)
    franklin.pendown()
    franklin.pensize(width=penwidth)

    # Pętla po całym l-system'ie tłumacząca kolejne znaki na ruch żółwia
    for i in range(len(lsystem)):
        c = lsystem[i]

        if c.isupper():
            franklin.forward(l)

        if c.islower():
            franklin.penup()
            franklin.forward(l)
            franklin.pendown()

        if c == '+':
            franklin.left(d)

        if c == '-':
            franklin.right(d)

        if c == '[':
            stack.append((franklin.heading(), franklin.pos()))

        if c == ']':
            heading, position = stack.pop()
            franklin.penup()
            franklin.goto(position)
            franklin.setheading(heading)
            franklin.pendown()

# %% [markdown]
# ### **Zadanie 2 - trójkąt Sierpińskiego**
#
# Sprawdź poprawność modyfikacji z zadania 1 tworząc [trójkąt Sierpińskiego](https://pl.wikipedia.org/wiki/Tr%C3%B3jk%C4%85t_Sierpi%C5%84skiego):
#
# zmienne : F G
#
# stałe : + −
#
# start : F−G−G
#
# reguły : (F → F−G+F+G−F), (G → GG)
#
# kąt : 120

# %%
rules = {'F': "F-G+F+G-F", 'G': "GG"}
lsystem = iterate(rules, 3, "F-G-G")
draw(lsystem, 120, 30, 13)

del lsystem
# Out:
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="100.0" x2="250.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="130.0" x2="224.019" y2="115.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="115.0" x2="224.019" y2="145.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="145.0" x2="250.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="130.0" x2="250.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="160.0" x2="224.019" y2="145.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="145.0" x2="198.038" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="198.038" y1="130.0" x2="198.038" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="198.038" y1="160.0" x2="172.057" y2="145.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="172.057" y1="145.0" x2="172.057" y2="175.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="172.057" y1="175.0" x2="198.038" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="198.038" y1="160.0" x2="198.038" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="198.038" y1="190.0" x2="224.019" y2="175.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="175.0" x2="250.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="160.0" x2="250.0" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="190.0" x2="224.019" y2="175.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="175.0" x2="224.019" y2="205.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="205.0" x2="250.0" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="190.0" x2="250.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="220.0" x2="224.019" y2="205.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.019" y1="205.0" x2="198.038" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="198.038" y1="190.0" x2="172.057" y2="175.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="172.057" y1="175.0" x2="146.076" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="146.076" y1="160.0" x2="146.076" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="146.076" y1="190.0" x2="120.095" y2="175.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="120.095" y1="175.0" x2="120.095" y2="205.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="120.095" y1="205.0" x2="146.076" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="146.076" y1="190.0" x2="146.076" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="146.076" y1="220.0" x2="120.095" y2="205.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="120.095" y1="205.0" x2="94.114" y2="190.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="94.114" y1="190.0" x2="94.114" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="94.114" y1="220.0" x2="68.133" y2="205.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="68.133" y1="205.0" x2="68.133" y2="235.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="68.133" y1="235.0" x2="94.114" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="94.114" y1="220.0" x2="94.114" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="94.114" y1="250.0" x2="120.095" y ...

# %% [markdown]
# ### **Zadanie 3 - drzewa**
#
# Narysuj drzewo zgodnie z poniższymi regułami:
#
# zmienne : $G, F$
#
# stałe : $+, −, [, ]$
#
# start  : $G$
#
# reguły  : $(G → F+[[G]-G]-F[-FG]+G)$, $(F → FF)$
#
# kąt  : 25°

# %%
rules = {'G': "F+[[G]-G]-F[-FG]+G", 'F': "FF"}
lsystem = iterate(rules, 3, "G")
draw(lsystem, 25, 20, 13)

del lsystem
# Out:
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="100.0" x2="250.0" y2="120.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="120.0" x2="250.0" y2="140.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="140.0" x2="250.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="160.0" x2="250.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="180.0" x2="258.452" y2="198.126" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="258.452" y1="198.126" x2="266.904" y2="216.252" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="266.904" y1="216.252" x2="282.225" y2="229.108" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="282.225" y1="229.108" x2="301.544" y2="234.284" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="282.225" y1="229.108" x2="297.546" y2="241.964" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="282.225" y1="229.108" x2="297.546" y2="241.964" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="297.546" y1="241.964" x2="305.998" y2="260.09" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="305.998" y1="260.09" x2="314.45" y2="278.216" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="297.546" y1="241.964" x2="316.865" y2="247.14" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="266.904" y1="216.252" x2="275.356" y2="234.378" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="290.677" y2="247.234" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="283.808" y2="252.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="283.808" y2="252.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="283.808" y2="272.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="272.504" x2="283.808" y2="292.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="299.129" y2="265.36" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="266.904" y1="216.252" x2="275.356" y2="234.378" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="283.808" y2="252.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="283.808" y2="272.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="272.504" x2="283.808" y2="292.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="292.504" x2="283.808" y2="312.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="312.504" x2="292.26" y2="330.63" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="312.504" x2="283.808" y2="332.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="312.504" x2="283.808" y2="332.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="332.504" x2="275.356" y2="350.63" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="350.63" x2="266.904" y2="368.756" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="332.504" x2="292.26" y2="350.63" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="299.129" y2="265.36" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="299.129" y1="265.36" x2="318.448" y2="270.536" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="299.129" y1="265.36" x2="314.45" y2="278.216" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="299.129" y1="265.36"  ...

# %% [markdown]
# ### **Zadanie 4 - drzewo stochastyczne**
#
# Narysuj drzewo z **zadania 3** korzystając z gramatyki stochastycznej, w której powyższe reguły stosowane są z prawdopodobieństwem 0.5, a z prawdopodobieństwem 0.5 nic się nie zmienia, tzn. stosowane są reguły $G \to G$ oraz $F \to F$.

# %%
import numpy as np

def iterate(rules, num=0, start='F'):
    """
    Tu wyliczane są kolejne iteracje układu, poczynając od start
    """

    def translate(current, rules):
        """
        W aktualnym stanie układu (current) podmienia wszystkie
        wystąpienia F na aksjomat, a stałe consts przepisuje
        """
        result = ''
        consts = {'+', '-', '[', ']'}
        for c in current:
            if c in consts:
                result += c
            else:
                x = np.random.uniform(0, 1)
                if x < 0.8: #zmiana na 0.8 przez błąd z prostą linią
                  result += rules[c]
                else:
                  result += c
        return result

    # Ustalamy początkowy rozkład na 'start'
    result = start
    for i in range(0, num):
        # Przy każdej iteracji stosujemy zdefiniowane reguły 'rules'
        result = translate(result, rules)
    return result


def draw(lsystem, d=90, l=10, speed=13, sx=500, sy=500, penwidth=3):
    """
       Prosi żółwia o narysowanie wyliczonego L-systemu

       lsystem  - lista
       d        - kąt o który skręca żółw, gdy przeczyta '+' lub '-'
       l        - długość kroku żółwia
       speed    - prędkość żołwia (13 to max)
       sx       - szerokość okna
       sy       - wysokość okna
       penwidth - grubość pisaka

    """
    # lista na którą wrzucamy pozycję żółwia jeśli pojawi się '['
    # lub z której pozycję żółwia zczytujemy jeśli pojawi się ']'
    stack  = []

    # Ustawienie okna i początkowa pozycja żółwia
    window_size_x = sx
    window_size_y = sy
    franklin.initializeTurtle(initial_speed=speed,
                              initial_window_size=(window_size_x, window_size_y))
    franklin.hideturtle()
    franklin.setheading(90)
    franklin.speed(speed)
    franklin.color('green')
    franklin.penup()
    franklin.goto(window_size_x*0.5,window_size_y*0.2)
    franklin.pendown()
    franklin.pensize(width=penwidth)

    # Pętla po całym l-system'ie tłumacząca kolejne znaki na ruch żółwia
    for i in range(len(lsystem)):
        c = lsystem[i]

        if c.isupper():
            franklin.forward(l)

        if c.islower():
            franklin.penup()
            franklin.forward(l)
            franklin.pendown()

        if c == '+':
            franklin.left(d)

        if c == '-':
            franklin.right(d)

        if c == '[':
            stack.append((franklin.heading(), franklin.pos()))

        if c == ']':
            heading, position = stack.pop()
            franklin.penup()
            franklin.goto(position)
            franklin.setheading(heading)
            franklin.pendown()

# %%
rules = {'G': "F+[[G]-G]-F[-FG]+G", 'F': "FF"}
lsystem = iterate(rules, 3, "G")
draw(lsystem, 25, 20, 13)

del lsystem
# Out:
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="100.0" x2="250.0" y2="120.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="120.0" x2="250.0" y2="140.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="140.0" x2="250.0" y2="160.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="160.0" x2="250.0" y2="180.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="180.0" x2="258.452" y2="198.126" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="258.452" y1="198.126" x2="266.904" y2="216.252" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="266.904" y1="216.252" x2="282.225" y2="229.108" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="282.225" y1="229.108" x2="301.544" y2="234.284" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="282.225" y1="229.108" x2="297.546" y2="241.964" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="282.225" y1="229.108" x2="297.546" y2="241.964" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="297.546" y1="241.964" x2="305.998" y2="260.09" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="305.998" y1="260.09" x2="314.45" y2="278.216" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="297.546" y1="241.964" x2="316.865" y2="247.14" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="266.904" y1="216.252" x2="275.356" y2="234.378" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="290.677" y2="247.234" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="283.808" y2="252.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="283.808" y2="252.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="283.808" y2="272.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="272.504" x2="283.808" y2="292.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="299.129" y2="265.36" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="266.904" y1="216.252" x2="275.356" y2="234.378" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="275.356" y1="234.378" x2="283.808" y2="252.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="283.808" y2="272.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="272.504" x2="283.808" y2="292.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="292.504" x2="283.808" y2="312.504" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="283.808" y1="252.504" x2="299.129" y2="265.36" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="299.129" y1="265.36" x2="318.448" y2="270.536" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="299.129" y1="265.36" x2="314.45" y2="278.216" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="299.129" y1="265.36" x2="314.45" y2="278.216" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="314.45" y1="278.216" x2="322.902" y2="296.342" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="322.902" y1="296.342" x2="331.354" y2="314.468" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="314.45" y1="278.216" x2="333.769" y2="283.392" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="180.0" x2="250.0" y2="200.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="200.0" x2="258.452" y2="218.126" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="258.452" y1="218.126" x2="273.7 ...

# %% [markdown]
# ### **Zadanie 5 (domowe, jeśli nie zdążymy)**
#
# Narysuj drzewo z **zadania 4** przyjmująć, że:
#
# a) kąt obrotu jest wybierany z równym prawdopodobieństwem z przedziału $[15^\circ,40^\circ]$,
#
# b) długość kroku wybierana jest równym prawdopodobieństwem z przedziału $[2,7]$

# %%
import numpy as np

def iterate(rules, num=0, start='F'):
    """
    Tu wyliczane są kolejne iteracje układu, poczynając od start
    """

    def translate(current, rules):
        """
        W aktualnym stanie układu (current) podmienia wszystkie
        wystąpienia F na aksjomat, a stałe consts przepisuje
        """
        result = ''
        consts = {'+', '-', '[', ']'}
        for c in current:
            if c in consts:
                result += c
            else:
                x = np.random.uniform(0, 1)
                if x < 0.8: #zmiana na 0.8 przez błąd z prostą linią
                  result += rules[c]
                else:
                  result += c
        return result

    # Ustalamy początkowy rozkład na 'start'
    result = start
    for i in range(0, num):
        # Przy każdej iteracji stosujemy zdefiniowane reguły 'rules'
        result = translate(result, rules)
    return result


def draw(lsystem, speed=13, sx=500, sy=500, penwidth=1):
    """
       Prosi żółwia o narysowanie wyliczonego L-systemu

       lsystem  - lista
       d        - kąt o który skręca żółw, gdy przeczyta '+' lub '-'
       l        - długość kroku żółwia
       speed    - prędkość żołwia (13 to max)
       sx       - szerokość okna
       sy       - wysokość okna
       penwidth - grubość pisaka

    """
    # lista na którą wrzucamy pozycję żółwia jeśli pojawi się '['
    # lub z której pozycję żółwia zczytujemy jeśli pojawi się ']'
    stack  = []

    # Ustawienie okna i początkowa pozycja żółwia
    window_size_x = sx
    window_size_y = sy
    franklin.initializeTurtle(initial_speed=speed,
                              initial_window_size=(window_size_x, window_size_y))
    franklin.hideturtle()
    franklin.setheading(90)
    franklin.speed(speed)
    franklin.color('green')
    franklin.penup()
    franklin.goto(window_size_x*0.5,window_size_y*0.2)
    franklin.pendown()
    franklin.pensize(width=penwidth)

    # Pętla po całym l-system'ie tłumacząca kolejne znaki na ruch żółwia
    for i in range(len(lsystem)):
        c = lsystem[i]
        d = int(np.random.uniform(15, 41))
        l = int(np.random.uniform(2, 8))

        if c.isupper():
            franklin.forward(l)

        if c.islower():
            franklin.penup()
            franklin.forward(l)
            franklin.pendown()

        if c == '+':
            franklin.left(d)

        if c == '-':
            franklin.right(d)

        if c == '[':
            stack.append((franklin.heading(), franklin.pos()))

        if c == ']':
            heading, position = stack.pop()
            franklin.penup()
            franklin.goto(position)
            franklin.setheading(heading)
            franklin.pendown()

# %%
rules = {'G': "F+[[G]-G]-F[-FG]+G", 'F': "FF"}
lsystem = iterate(rules, 5, "G")
draw(lsystem, 13)

del lsystem
# Out:
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="100.0" x2="250.0" y2="106.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="106.0" x2="250.0" y2="113.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="113.0" x2="250.0" y2="119.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="119.0" x2="250.0" y2="125.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="125.0" x2="250.0" y2="130.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="130.0" x2="250.0" y2="137.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="137.0" x2="250.0" y2="142.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="142.0" x2="250.0" y2="148.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="148.0" x2="250.0" y2="154.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="154.0" x2="250.0" y2="161.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="161.0" x2="250.0" y2="165.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="165.0" x2="250.0" y2="168.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="168.0" x2="250.0" y2="171.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="171.0" x2="250.0" y2="177.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="177.0" x2="250.0" y2="182.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="182.0" x2="250.0" y2="184.0" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="250.0" y1="184.0" x2="251.169" y2="187.825" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="251.169" y1="187.825" x2="252.923" y2="193.563" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="252.923" y1="193.563" x2="253.508" y2="195.476" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="253.508" y1="195.476" x2="255.262" y2="201.214" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="255.262" y1="201.214" x2="255.847" y2="203.127" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="255.847" y1="203.127" x2="257.309" y2="207.909" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="257.309" y1="207.909" x2="258.771" y2="212.691" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="258.771" y1="212.691" x2="260.525" y2="218.429" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="260.525" y1="218.429" x2="265.117" y2="223.712" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="265.117" y1="223.712" x2="269.709" y2="228.995" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="269.709" y1="228.995" x2="271.677" y2="231.259" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="271.677" y1="231.259" x2="275.106" y2="233.319" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="275.106" y1="233.319" x2="276.82" y2="234.349" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="276.82" y1="234.349" x2="278.752" y2="234.867" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="278.752" y1="234.867" x2="285.371" y2="232.588" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="278.752" y1="234.867" x2="280.631" y2="235.551" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="278.752" y1="234.867" x2="280.752" y2="234.867" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="280.752" y1="234.867" x2="283.083" y2="236.755" stroke-linecap="round" style="stroke:green;stroke-width:1"/><line x1="283.083" y1="236.755" x2="285.414" y2="238.643" stroke-linecap="round" style="stroke:green;stroke-width: ...

# %%
#zadanie domowe wyżej
#roślina #1 z alife.pl
#wymaga metody z zadania 1

rules = {'F': "F[+F]F[-F]F"}
lsystem = iterate(rules, 4, "F")
draw(lsystem, 25.7, 7, 13, 500, 800, 3)

del lsystem
# Out:
#       <svg width="500" height="800">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="160.0" x2="250.0" y2="167.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="167.0" x2="253.036" y2="173.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="167.0" x2="250.0" y2="174.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="174.0" x2="246.964" y2="180.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="174.0" x2="250.0" y2="181.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="181.0" x2="253.036" y2="187.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="253.036" y1="187.308" x2="258.507" y2="191.675" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="253.036" y1="187.308" x2="256.072" y2="193.616" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="256.072" y1="193.616" x2="256.072" y2="200.616" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="256.072" y1="193.616" x2="259.108" y2="199.924" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="181.0" x2="250.0" y2="188.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="188.0" x2="253.036" y2="194.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="188.0" x2="250.0" y2="195.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="195.0" x2="246.964" y2="201.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="195.0" x2="250.0" y2="202.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="202.0" x2="246.964" y2="208.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="246.964" y1="208.308" x2="246.964" y2="215.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="246.964" y1="208.308" x2="243.928" y2="214.616" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="243.928" y1="214.616" x2="238.457" y2="218.983" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="243.928" y1="214.616" x2="240.892" y2="220.924" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="202.0" x2="250.0" y2="209.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="209.0" x2="253.036" y2="215.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="209.0" x2="250.0" y2="216.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="216.0" x2="246.964" y2="222.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="216.0" x2="250.0" y2="223.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="223.0" x2="253.036" y2="229.308" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="253.036" y1="229.308" x2="258.507" y2="233.675" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="253.036" y1="229.308" x2="256.072" y2="235.616" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="256.072" y1="235.616" x2="256.072" y2="242.616" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="256.072" y1="235.616" x2="259.108" y2="241.924" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="259.108" y1="241.924" x2="264.579" y2="246.291" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="264.579" y1="246.291" x2="271.402" y2="247.854" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="264.579" y1="246.291" x2="270.05" y2="250.658" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="270.05" y1="250.658" x2="273.086" y2="256.966" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="270.05" y1="250.658" x2="275.521" y2="255.025" stroke-linecap="round" style="str ...

# %%
#zadanie domowe wyżej
#jakiś dziwny przypadkowy twór
#wymaga metody z zadania 1

rules = {'G': "F+[[G]-E]+G[-EG]+G", 'E': "G+[E]+F[-F]", 'F': "F-E-E-G"}
lsystem = iterate(rules, 3, "G-E")
draw(lsystem, 13)

del lsystem
# Out:
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="250.0" y1="100.0" x2="250.0" y2="110.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="250.0" y1="110.0" x2="247.75" y2="119.744" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="247.75" y1="119.744" x2="243.366" y2="128.732" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="243.366" y1="128.732" x2="237.073" y2="136.503" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="237.073" y1="136.503" x2="229.193" y2="142.66" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="229.193" y1="142.66" x2="222.9" y2="150.431" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="229.193" y1="142.66" x2="224.809" y2="151.648" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.809" y1="151.648" x2="218.516" y2="159.419" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="224.809" y1="151.648" x2="218.516" y2="159.419" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="159.419" x2="214.132" y2="168.407" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="159.419" x2="216.266" y2="169.163" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="216.266" y1="169.163" x2="211.882" y2="178.151" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="216.266" y1="169.163" x2="211.882" y2="178.151" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="211.882" y1="178.151" x2="209.632" y2="187.895" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="211.882" y1="178.151" x2="207.498" y2="187.139" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="211.882" y1="178.151" x2="211.882" y2="188.151" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="211.882" y1="188.151" x2="209.632" y2="197.895" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="209.632" y1="197.895" x2="207.382" y2="207.639" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="211.882" y1="188.151" x2="214.132" y2="197.895" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="214.132" y1="197.895" x2="218.516" y2="206.883" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="206.883" x2="220.766" y2="216.627" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.766" y1="216.627" x2="220.766" y2="226.627" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="220.766" y1="226.627" x2="218.516" y2="236.371" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="236.371" x2="218.516" y2="246.371" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="246.371" x2="220.766" y2="256.115" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="246.371" x2="218.516" y2="256.371" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="246.371" x2="222.9" y2="255.359" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="222.9" y1="255.359" x2="225.15" y2="265.103" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="225.15" y1="265.103" x2="227.4" y2="274.847" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="222.9" y1="255.359" x2="229.193" y2="263.13" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="236.371" x2="216.266" y2="246.115" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="216.266" y1="246.115" x2="216.266" y2="256.115" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="216.266" y1="246.115" x2="218.516" y2="255.859" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="218.516" y1="255.859" x2="218.516" y2="265.859" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1=" ...
