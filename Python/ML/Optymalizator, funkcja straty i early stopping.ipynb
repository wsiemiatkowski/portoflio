# %% [markdown]
# ### 1. Import bibliotek
# #### 🇬🇧 Import libraries

# %%
# !pip install mnist

import tensorflow as tf
import numpy as np
import mnist

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from matplotlib import pyplot
from tensorflow.keras.utils import to_categorical

from tensorflow import keras
from tensorflow.keras import backend as K
# Out:
# Requirement already satisfied: mnist in /usr/local/lib/python3.7/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mnist) (1.21.6)

# %% [markdown]
# ### 2. Przygotowanie danych do analizy
# #### 🇬🇧 Data preparation

# %%
train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

# %% [markdown]
# Wybór odpowiedniego optymalizatora, metryk oraz funkcji straty.

# %%
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# %%
model.fit(
    train_images,
    to_categorical(train_labels),
    epochs=5,
    batch_size=30,
)
# Out:
# Epoch 1/5
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0979 - accuracy: 0.9690
# Epoch 2/5
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.0899 - accuracy: 0.9713
# Epoch 3/5
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0830 - accuracy: 0.9739
# Epoch 4/5
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0786 - accuracy: 0.9755
# Epoch 5/5
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.0705 - accuracy: 0.9778

# %% [markdown]
# ### 3. Trenowanie modelu
# #### 🇬🇧 Model training

# %%
#1
f1 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

#2
f2 = ModelCheckpoint('model', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

#3
history = model.fit(train_images, to_categorical(train_labels), batch_size = 32, validation_data=(test_images, to_categorical(test_labels)), epochs=15, verbose=1, callbacks=[f1, f2])
# batch size to liczba przez którą dzielony jest nasz zbiór (np. u na 60.000 / 32 = 1875)

#4
trained_model = load_model('model')

#5
train_accuracy = trained_model.evaluate(train_images, to_categorical(train_labels), verbose = 1)

#6
test_accuracy = trained_model.evaluate(test_images, to_categorical(test_labels), verbose = 1)

#8
print(train_accuracy + test_accuracy)

#9
pyplot.plot(range(1, 16), history.history['val_loss'], 'b', label='validation loss')
pyplot.title('Validation loss')
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/15
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9816
# Epoch 1: val_accuracy improved from -inf to 0.97080, saving model to model
# INFO:tensorflow:Assets written to: model/assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0548 - accuracy: 0.9816 - val_loss: 0.1122 - val_accuracy: 0.9708
# Epoch 2/15
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9818
# Epoch 2: val_accuracy did not improve from 0.97080
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0538 - accuracy: 0.9818 - val_loss: 0.1140 - val_accuracy: 0.9690
# Epoch 3/15
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9828
# Epoch 3: val_accuracy did not improve from 0.97080
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0511 - accuracy: 0.9828 - val_loss: 0.1211 - val_accuracy: 0.9681
# Epoch 4/15
# 1862/1875 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9827
# Epoch 4: val_accuracy did not improve from 0.97080
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0506 - accuracy: 0.9827 - val_loss: 0.1116 - val_accuracy: 0.9698
# Epoch 5/15
# 1863/1875 [============================>.] - ETA: 0s - loss: 0.0462 - accuracy: 0.9844
# Epoch 5: val_accuracy improved from 0.97080 to 0.97180, saving model to model
# INFO:tensorflow:Assets written to: model/assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0461 - accuracy: 0.9845 - val_loss: 0.1089 - val_accuracy: 0.9718
# Epoch 6/15
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9846
# Epoch 6: val_accuracy did not improve from 0.97180
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0458 - accuracy: 0.9847 - val_loss: 0.1069 - val_accuracy: 0.9709
# Epoch 7/15
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.0452 - accuracy: 0.9849
# Epoch 7: val_accuracy did not improve from 0.97180
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0452 - accuracy: 0.9848 - val_loss: 0.1279 - val_accuracy: 0.9667
# Epoch 8/15
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9850
# Epoch 8: val_accuracy did not improve from 0.97180
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0454 - accuracy: 0.9850 - val_loss: 0.1108 - val_accuracy: 0.9712
# Epoch 9/15
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9869
# Epoch 9: val_accuracy did not improve from 0.97180
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 0.1193 - val_accuracy: 0.9694
# Epoch 10/15
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9858
# Epoch 10: val_accuracy improved from 0.97180 to 0.97300, saving model to model
# INFO:tensorflow:Assets written to: model/assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0417 - accuracy: 0.9858 - val_loss: 0.1101 - val_accuracy: 0.9730
# Epoch 11/15
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.0374 - accuracy: 0.9873
# Epoch 11: val_accuracy did not improve from 0.97300
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0373 - accuracy: 0.9873 - val_loss: 0.1119 - val_accuracy: 0.9717
# Epoch 12/15
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9863
# Epoch 12: val_accuracy did not improve from 0.97300
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0408 - accuracy: 0.9863 - val_loss: 0.1280 - val_accuracy: 0.9698
# Epoch 13/15
# 1864/1875 [============================>.] - ETA: 0s - loss: 0.0372 - accuracy: 0.9873
# Epoch 13: val_accuracy did not improve from 0.97300
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0374 - accuracy: 0.9872 - val_loss: 0.1173 - val_accuracy: 0.9705
# Epoch 14/15
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0355 - accuracy: 0.9886
# Epoch 14: val_accuracy did not improve from 0.97300
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0355 - accuracy: 0.9886 - val_loss: 0.1470 - val_accuracy: 0.9648
# Epoch 15/15
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9877
# Epoch 15: val_accuracy did not improve from 0.97300
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0362 - accuracy: 0.9877 - val_loss: 0.1316 - val_accuracy: 0.9689
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0318 - accuracy: 0.9892
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1101 - accuracy: 0.9730
# [0.031842779368162155, 0.9891833066940308, 0.11014344543218613, 0.9729999899864197]

# %% [markdown]
# ### 📚 Zadanie 1.
# ##### Przeprowadź proces uczenia się z wykorzystaniem early stopping, wykonaj poniższe kroki.
# ##### Train the neural network using early stopping, follow the steps below.

# %% [markdown]
# 1. Stwórz nową zmienną, którą nazwiesz f1, odwołaj się do early stopping, wprowadź odpowiednie wartości (takie jakie chcesz, tylko dla zmiennej patience wprowadź "10"), do parametrów takich jak monitor, mode, verbose oraz patience.
# 2. Stwórz nową zmienną, którą nazwiesz f2, odwołaj się do ModelCheckpoint, wprowadź nazwę dla swojego modelu oraz odpowiednie wartości dla parametru monitor, mode, verbose oraz save_best_only (znowu - takie jakie chcesz, poeksperymentuj z nimi 🔬).
# 3. Stwórz nową zmienną, którą nazwiesz history. Zmienna ta powinna zawierać stworzone w poprzednim kroku dane treningowe (x), etykiety danych trningowych (y), dane testowe (a), etykiey danych testowych (b) oraz odpowiednie wartości parametrów epochs oraz verbose. W przypadku etykiet przydatną funkcją może być to_categorical().
# 4. Stwórz nową zmienną, którą nazwiesz trained_model, załaduj model używając nazwy modelu z punktu drugiego.
# 5. Stwórz nową zmienną, którą nazwiesz train_accuracy, odwołaj się do trained_model.evaluate, użyj danych treningowych (x) oraz etykiet danych treningowych (y).
# 6. Stwórz nową zmienną, którą nazwiesz test_accuracy, odwołaj się do trained_model.evaluate, użyj danych testowych (a) oraz etykiet danych testowych (b).
# 7. Przeprowadź uczenie sieci dla liczby epok wynoszącej 100. Po której epoce proces trenowania sieci się zatrzyma?
# 8. Wyświetl informacje dotyczące dokładności klasyfikacji na materiale treningowym oraz testowym.
# 9. Wygeneruj wykres przedstawiający proces uczenia się sieci.

# %% [markdown]
# 1. Create the new variable "f1", refer to early stopping class, enter the appropriate values (whatever you want, but enter "10" for the patience variable) for parameters such as monitor, mode, verbose and patience.
# 2. Create the new variable "f2", refer to ModelCheckpoint class, enter a name for your model and the appropriate values for the monitor, mode, verbose and save_best_only parameters (again - whatever you want, experiment 🔬).
# 3. Create the new variable "history". This variable should contain the training data (x), trning data labels (y), test data (a), test data labels (b) and the corresponding epochs and verbose parameters created in the previous step. For labels, to_categorical () can be a useful function.
# 4. Create the new variable "trained_model", load the model using the model name from the second point.
# 5. Create the new variable "train_accuracy", refer to trained_model.evaluate class, use training data (x) and training data labels (y).
# 6. Create the new variable "test_accuracy", refer to trained_model.evaluate class, use test data (a) and test data labels (b).
# 7. Perform network training for 100 epochs. When will it end?
# 8. Show information concerning accuracy of the classification on the training and test material.
# 9. Generate a chart showing the network learning process.

# %% [markdown]
# ### 📚 Zadanie 2.
# ##### Uruchom ponownie proces treningu sieci, tym razem wprowadzając zmianę związaną z funkcją straty oraz optymalizatora.
# ##### Run again the network training , this time making a change related to the loss functions and optimizers.

# %% [markdown]
# 1. Wypróbuj inną funkcję straty (rozkład Poisona). Czy w przypadku naszego zbioru danych taka funkcja ma sens?
# 2. Wypróbuj inny optymalizator (z wykorzystaniem algorytmu Adadelta). Czy obserwujesz jakieś zmiany w procesie uczenia się w porównaniu do algorytmu wykorzystanego w tutorialu (adam)? Gdzie może leżeć przyczyna tych różnic? (zob. https://keras.io/api/optimizers/adadelta).

# %% [markdown]
# 1. Try another loss function (Poison). Does such a function make sense in the case of our data set?
# 2. Try another optimizer (use the Adadelta algorithm). Do you see any changes in model parametrs compared to the algorithm used in the tutorial (adam)? Why do we see differences? (see https://keras.io/api/optimizers/adadelta).

# %%
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

model.compile(
  optimizer='adam',
  loss='poisson',
  metrics=['accuracy'],
)

# %% [markdown]
# Taka funkcja powoduje prawie stałą stratę na każdym poziomie nauczania, która zaczyna od dobrej wartości, ale ta wartość nie ulega dalszej poprawie w przeciwieństwie do oryginalnej funkcji. Stąd nie jest raczej odpowiednia dla naszych danych.

# %%
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

model.compile(
  optimizer='adadelta',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# %% [markdown]
# Proces przebiega inaczej. Zaczynamy od bardzo dużej wartości straty oraz słabej dokładności, z czasem model poprawia się, ale raczej wymagałby dodatkowej liczby epoch, aby dostać rezultaty podobne do oryginału.

# %% [markdown]
# ### 📚 Zadanie 3.

# %% [markdown]
# Poniższy przykład ilustruje w jaki sposób możemy skorzystać z funkcji straty Root Mean Square Error (RMSE) dla dwóch zmiennych (y_true i y_pred).

# %%
y_true = 43.2
y_pred = 4.2

# %%
x = tf.keras.metrics.RootMeanSquaredError()
x(y_true, y_pred).numpy()
# Out:
# 39.0

# %% [markdown]
# Czasami jednak możemy chcieć stworzyć naszą własną funkcję straty (podajemy przy tym dwa argumenty, tj. y_true oraz y_pred).

# %%
def custom_loss_function(y_true, y_pred):
    pass

# %% [markdown]
# ##### Niekiedy przydaje nam się możliwość wprowadzenia modyfikacji do funkcji straty lub zbudowania własnej funkcji straty od postaw. W Keras/Tensorflow jest to dosyć prosta rzecz, którą możemy zrealizować za pomocą podstawowych operacji.
# Odtwórz wskazaną wcześniej funkcję straty Root Mean Squared Error tworząc od podstaw nową funkcję.
# ##### Sometimes it is useful to modify the loss function or build your own loss function from scratch. In Keras / Tensorflow it is quite a simple operation.
# Recreate the Root Mean Squared Error function shown earlier by creating a new function from scratch.

# %% [markdown]
# ![2fae41d2-cda7-466c-b672-f909e745e126.png](data:image/png;base64,...)

# %%
def cf_rmse(y_true, y_pred):
    error = y_pred - y_true
    sqr_error = error**2
    mean_sqr_error = np.mean(sqr_error)
    sqrt_mean_sqr_error = np.sqrt(mean_sqr_error)
    return sqrt_mean_sqr_error

cf_rmse(y_true, y_pred)
# Out:
# 39.0
